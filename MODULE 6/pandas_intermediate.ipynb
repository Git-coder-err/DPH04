# %% [markdown]
# # **Pandas Intermediate**
#
# ### **Import pandas**

# %%
import pandas as pd

# %%
df = pd.read_csv("adult.csv")
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married                  ?    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]

# %% [markdown]
# ## **Data Inspection**
#
# Data inspection is the initial review of a dataset to find missing values,
# incorrect data types, and gather basic statistics, providing insights into its quality and structure.

# %%
# Identify the Missing Values
# True = Empty, False = Not Empty

df.isnull()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
#        occupation  relationship   race  gender  capital-gain  capital-loss  \
# 0           False         False  False   False         False         False
# 1           False         False  False   False         False         False
# 2           False         False  False   False         False         False
# 3           False         False  False   False         False         False
# 4           False         False  False   False         False         False
# ...           ...           ...    ...     ...           ...           ...
# 48837       False         False  False   False         False         False
# 48838       False         False  False   False         False         False
# 48839       False         False  False   False         False         False
# 48840       False         False  False   False         False         False
# 48841       False         False  False   False         False         False
#
#        hours-per-week  native-country  income
# 0               False           False   False
# 1               False           False   False
# 2               False           False   False
# 3               False           False   False
# 4               False           False   False
# ...               ...             ...     ...
# 48837           False           False   False
# 48838           False           False   False
# 48839           False           False   False
# 48840           False           False   False
# 48841           False           False   False
#
# [48842 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married                  ?    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]

# %%
# Finding cells that have missing values represented with '?'
(df == "?").sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
# Identify the Data Type of each of the columns
df.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
# Initial Analysis
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# ## **Cleaning Data**
# Cleaning data involves eliminating or rectifying inaccuracies, inconsistencies,
# and missing values within your dataset, utilizing techniques such as handling
# missing values via deletion or imputation, rectifying data types, and detecting
# and eliminating duplicate entries, ultimately resulting in more precise and dependable analysis.

# %% [markdown]
# ## **Cleaning Data**
#
# Cleaning data involves eliminating or rectifying inaccuracies, inconsistencies,
# and missing values within your dataset, utilizing techniques such as handling
# missing values via deletion or imputation, rectifying data types, and detecting
# and eliminating duplicate entries, ultimately resulting in more precise and dependable analysis.

# %%
# Objective Number 1: Turn the '?' into a null value
df.replace('?', pd.NA, inplace=True)
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18          <NA>  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married               <NA>    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]

# %%
# Objective Number 1: Turn the '?' into a null value
df.replace('?', pd.NA, inplace=True)
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18          <NA>  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married               <NA>    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]

# %%
# Replace null with unemployed
df["occupation"] = df["occupation"].fillna("Unemployed")
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18          <NA>  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing      Husband  White    Male
# 2      Married-civ-spouse    Protective-serv      Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct      Husband  Black    Male
# 4           Never-married         Unemployed    Own-child  White  Female
# ...                   ...                ...          ...    ...     ...
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 4                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [48842 rows x 15 columns]

# %%
# Checking every column for null values
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation            0
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
# Drop the rows that have null values
df.dropna(inplace=True)
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2      Married-civ-spouse    Protective-serv        Husband  White    Male
# 3      Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 5           Never-married      Other-service  Not-in-family  White    Male
# ...                   ...                ...            ...    ...     ...
# 48837  Married-civ-spouse       Tech-support           Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 48839             Widowed       Adm-clerical      Unmarried  White  Female
# 48840       Never-married       Adm-clerical      Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 5                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [45232 rows x 15 columns]

# %% [markdown]
# ### **Trimming and Cleaning Text Data**

# %%
# Removing the spaces at the beginning and at the end of the string.
df['workclass'] = df["workclass"].str.strip()
df['workclass']
# Out:
# 0             Private
# 1             Private
# 2           Local-gov
# 3             Private
# 5             Private
#              ...
# 48837         Private
# 48838         Private
# 48839         Private
# 48840         Private
# 48841    Self-emp-inc
# Name: workclass, Length: 45232, dtype: object

# %%
occupation_mapping = {
    'Machine-op-inspct': 'Machine Operator',
    'Farming-fishing': 'Farming and Fishing',
    'Protective-serv': 'Protective Services'
}

df['occupation'] = df['occupation'].map(occupation_mapping).fillna(df['occupation'])

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status           occupation   relationship   race  gender  \
# 0           Never-married     Machine Operator      Own-child  Black    Male
# 1      Married-civ-spouse  Farming and Fishing        Husband  White    Male
# 2      Married-civ-spouse  Protective Services        Husband  White    Male
# 3      Married-civ-spouse     Machine Operator        Husband  Black    Male
# 5           Never-married        Other-service  Not-in-family  White    Male
# ...                   ...                  ...            ...    ...     ...
# 48837  Married-civ-spouse         Tech-support           Wife  White  Female
# 48838  Married-civ-spouse     Machine Operator        Husband  White    Male
# 48839             Widowed         Adm-clerical      Unmarried  White  Female
# 48840       Never-married         Adm-clerical      Own-child  White    Male
# 48841  Married-civ-spouse      Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 5                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [45232 rows x 15 columns]

# %%
# Removing the hyphen and replace into space
df['marital-status'] = df['marital-status'].replace('-', ' ', regex=True)

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status           occupation   relationship   race  gender  \
# 0           Never married     Machine Operator      Own-child  Black    Male
# 1      Married civ spouse  Farming and Fishing        Husband  White    Male
# 2      Married civ spouse  Protective Services        Husband  White    Male
# 3      Married civ spouse     Machine Operator        Husband  Black    Male
# 5           Never married        Other-service  Not-in-family  White    Male
# ...                   ...                  ...            ...    ...     ...
# 48837  Married civ spouse         Tech-support           Wife  White  Female
# 48838  Married civ spouse     Machine Operator        Husband  White    Male
# 48839             Widowed         Adm-clerical      Unmarried  White  Female
# 48840       Never married         Adm-clerical      Own-child  White    Male
# 48841  Married civ spouse      Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 0                 0             0              40  United-States  <=50K
# 1                 0             0              50  United-States  <=50K
# 2                 0             0              40  United-States   >50K
# 3              7688             0              40  United-States   >50K
# 5                 0             0              30  United-States  <=50K
# ...             ...           ...             ...            ...    ...
# 48837             0             0              38  United-States  <=50K
# 48838             0             0              40  United-States   >50K
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K
#
# [45232 rows x 15 columns]

# %%
# Change the data type of income column
df['income'] = df['income'].astype('category')

# %%
df.dtypes
# Out:
# age                   int64
# workclass            object
# fnlwgt                int64
# education            object
# educational-num       int64
# marital-status       object
# occupation           object
# relationship         object
# race                 object
# gender               object
# capital-gain          int64
# capital-loss          int64
# hours-per-week        int64
# native-country       object
# income             category
# dtype: object

# %% [markdown]
# ### **Renaming columns and Reindexing**

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
# Rename the column name
df.rename(columns={"native-country":"country", "hours-per-week": "working hours"}, inplace=True)
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status           occupation   relationship   race  gender  \
# 0           Never married     Machine Operator      Own-child  Black    Male
# 1      Married civ spouse  Farming and Fishing        Husband  White    Male
# 2      Married civ spouse  Protective Services        Husband  White    Male
# 3      Married civ spouse     Machine Operator        Husband  Black    Male
# 5           Never married        Other-service  Not-in-family  White    Male
# ...                   ...                  ...            ...    ...     ...
# 48837  Married civ spouse         Tech-support           Wife  White  Female
# 48838  Married civ spouse     Machine Operator        Husband  White    Male
# 48839             Widowed         Adm-clerical      Unmarried  White  Female
# 48840       Never married         Adm-clerical      Own-child  White    Male
# 48841  Married civ spouse      Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  working hours        country income
# 0                 0             0             40  United-States  <=50K
# 1                 0             0             50  United-States  <=50K
# 2                 0             0             40  United-States   >50K
# 3              7688             0             40  United-States   >50K
# 5                 0             0             30  United-States  <=50K
# ...             ...           ...            ...            ...    ...
# 48837             0             0             38  United-States  <=50K
# 48838             0             0             40  United-States   >50K
# 48839             0             0             40  United-States  <=50K
# 48840             0             0             20  United-States  <=50K
# 48841         15024             0             40  United-States   >50K
#
# [45232 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'working hours', 'country', 'income'],
#       dtype='object')

# %%
# Reindexing - focus on the columns, change the order of the column.
df.reindex(columns=["age", "gender", "occupation"])
# Out:
#        age  gender           occupation
# 0       25    Male     Machine Operator
# 1       38    Male  Farming and Fishing
# 2       28    Male  Protective Services
# 3       44    Male     Machine Operator
# 5       34    Male        Other-service
# ...    ...     ...                  ...
# 48837   27  Female         Tech-support
# 48838   40    Male     Machine Operator
# 48839   58  Female         Adm-clerical
# 48840   22    Male         Adm-clerical
# 48841   52  Female      Exec-managerial
#
# [45232 rows x 3 columns]

# %% [markdown]
# ### **Removing Columns and Rows**

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status           occupation   relationship   race  gender  \
# 0           Never married     Machine Operator      Own-child  Black    Male
# 1      Married civ spouse  Farming and Fishing        Husband  White    Male
# 2      Married civ spouse  Protective Services        Husband  White    Male
# 3      Married civ spouse     Machine Operator        Husband  Black    Male
# 5           Never married        Other-service  Not-in-family  White    Male
# ...                   ...                  ...            ...    ...     ...
# 48837  Married civ spouse         Tech-support           Wife  White  Female
# 48838  Married civ spouse     Machine Operator        Husband  White    Male
# 48839             Widowed         Adm-clerical      Unmarried  White  Female
# 48840       Never married         Adm-clerical      Own-child  White    Male
# 48841  Married civ spouse      Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  working hours        country income
# 0                 0             0             40  United-States  <=50K
# 1                 0             0             50  United-States  <=50K
# 2                 0             0             40  United-States   >50K
# 3              7688             0             40  United-States   >50K
# 5                 0             0             30  United-States  <=50K
# ...             ...           ...            ...            ...    ...
# 48837             0             0             38  United-States  <=50K
# 48838             0             0             40  United-States   >50K
# 48839             0             0             40  United-States  <=50K
# 48840             0             0             20  United-States  <=50K
# 48841         15024             0             40  United-States   >50K
#
# [45232 rows x 15 columns]

# %%
# Row (Single)
shortened_df = df.drop(0)
shortened_df
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 1       38           Private   89814       HS-grad                9
# 2       28         Local-gov  336951    Assoc-acdm               12
# 3       44           Private  160323  Some-college               10
# 5       34           Private  198693          10th                6
# 7       63  Self-emp-not-inc  104626   Prof-school               15
# ...    ...               ...     ...           ...              ...
# 48837   27           Private  257302    Assoc-acdm               12
# 48838   40           Private  154374       HS-grad                9
# 48839   58           Private  151910       HS-grad                9
# 48840   22           Private  201490       HS-grad                9
# 48841   52      Self-emp-inc  287927       HS-grad                9
#
#            marital-status           occupation   relationship   race  gender  \
# 1      Married civ spouse  Farming and Fishing        Husband  White    Male
# 2      Married civ spouse  Protective Services        Husband  White    Male
# 3      Married civ spouse     Machine Operator        Husband  Black    Male
# 5           Never married        Other-service  Not-in-family  White    Male
# 7      Married civ spouse       Prof-specialty        Husband  White    Male
# ...                   ...                  ...            ...    ...     ...
# 48837  Married civ spouse         Tech-support           Wife  White  Female
# 48838  Married civ spouse     Machine Operator        Husband  White    Male
# 48839             Widowed         Adm-clerical      Unmarried  White  Female
# 48840       Never married         Adm-clerical      Own-child  White    Male
# 48841  Married civ spouse      Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  working hours        country income
# 1                 0             0             50  United-States  <=50K
# 2                 0             0             40  United-States   >50K
# 3              7688             0             40  United-States   >50K
# 5                 0             0             30  United-States  <=50K
# 7              3103             0             32  United-States   >50K
# ...             ...           ...            ...            ...    ...
# 48837             0             0             38  United-States  <=50K
# 48838             0             0             40  United-States   >50K
# 48839             0             0             40  United-States  <=50K
# 48840             0             0             20  United-States  <=50K
# 48841         15024             0             40  United-States   >50K
#
# [45231 rows x 15 columns]

# %%
# Row (Multiple)
shortened_df = df.drop([1, 2, 3])
shortened_df
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 0       25           Private  226802          11th                7
# 5       34           Private  198693          10th                6
# 7       63  Self-emp-not-inc  104626   Prof-school               15
# 8       24           Private  369667  Some-college               10
# 9       55           Private  104996       7th-8th                4
# ...    ...               ...     ...           ...              ...
# 48837   27           Private  257302    Assoc-acdm               12
# 48838   40           Private  154374       HS-grad                9
# 48839   58           Private  151910       HS-grad                9
# 48840   22           Private  201490       HS-grad                9
# 48841   52      Self-emp-inc  287927       HS-grad                9
#
#            marital-status        occupation   relationship   race  gender  \
# 0           Never married  Machine Operator      Own-child  Black    Male
# 5           Never married     Other-service  Not-in-family  White    Male
# 7      Married civ spouse    Prof-specialty        Husband  White    Male
# 8           Never married     Other-service      Unmarried  White  Female
# 9      Married civ spouse      Craft-repair        Husband  White    Male
# ...                   ...               ...            ...    ...     ...
# 48837  Married civ spouse      Tech-support           Wife  White  Female
# 48838  Married civ spouse  Machine Operator        Husband  White    Male
# 48839             Widowed      Adm-clerical      Unmarried  White  Female
# 48840       Never married      Adm-clerical      Own-child  White    Male
# 48841  Married civ spouse   Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  working hours        country income
# 0                 0             0             40  United-States  <=50K
# 5                 0             0             30  United-States  <=50K
# 7              3103             0             32  United-States   >50K
# 8                 0             0             40  United-States  <=50K
# 9                 0             0             10  United-States  <=50K
# ...             ...           ...            ...            ...    ...
# 48837             0             0             38  United-States  <=50K
# 48838             0             0             40  United-States   >50K
# 48839             0             0             40  United-States  <=50K
# 48840             0             0             20  United-States  <=50K
# 48841         15024             0             40  United-States   >50K
#
# [45229 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'working hours', 'country', 'income'],
#       dtype='object')

# %%
# Column (Multiple)
shortened_df = df.drop(['relationship', 'race', 'gender'], axis=1)
shortened_df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'capital-gain', 'capital-loss',
#        'working hours', 'country', 'income'],
#       dtype='object')

# %%
# Column (Multiple)
shortened_df = df.drop(columns=['occupation', 'capital-gain', 'capital-loss'])
shortened_df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'relationship', 'race', 'gender', 'working hours',
#        'country', 'income'],
#       dtype='object')

# %%
df.axes
# Out:
# [Index([    0,     1,     2,     3,     5,     7,     8,     9,    10,    11,
#         ...
#         48832, 48833, 48834, 48835, 48836, 48837, 48838, 48839, 48840, 48841],
#        dtype='int64', length=45232),
#  Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#         'marital-status', 'occupation', 'relationship', 'race', 'gender',
#         'capital-gain', 'capital-loss', 'working hours', 'country', 'income'],
#        dtype='object')]

# %% [markdown]
# ## **Handling Duplicates**
#
# Identifying and removing duplicate records are crucial for maintaining data quality.
# Pandas provides .duplicated() and .drop_duplicates() for finding and removing duplicates,
# ensuring each data point is unique for accurate analysis.

# %%
# True = Duplicated, False = Unique
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 5        False
#          ...
# 48837    False
# 48838    False
# 48839    False
# 48840    False
# 48841    False
# Length: 45232, dtype: bool

# %%
print("Duplicated Rows:", df.duplicated().sum())
# Out:
# Duplicated Rows: 47

# %%
# Delete the duplicate rows
df.drop_duplicates(inplace=True)
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status           occupation   relationship   race  gender  \
# 0           Never married     Machine Operator      Own-child  Black    Male
# 1      Married civ spouse  Farming and Fishing        Husband  White    Male
# 2      Married civ spouse  Protective Services        Husband  White    Male
# 3      Married civ spouse     Machine Operator        Husband  Black    Male
# 5           Never married        Other-service  Not-in-family  White    Male
# ...                   ...                  ...            ...    ...     ...
# 48837  Married civ spouse         Tech-support           Wife  White  Female
# 48838  Married civ spouse     Machine Operator        Husband  White    Male
# 48839             Widowed         Adm-clerical      Unmarried  White  Female
# 48840       Never married         Adm-clerical      Own-child  White    Male
# 48841  Married civ spouse      Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  working hours        country income
# 0                 0             0             40  United-States  <=50K
# 1                 0             0             50  United-States  <=50K
# 2                 0             0             40  United-States   >50K
# 3              7688             0             40  United-States   >50K
# 5                 0             0             30  United-States  <=50K
# ...             ...           ...            ...            ...    ...
# 48837             0             0             38  United-States  <=50K
# 48838             0             0             40  United-States   >50K
# 48839             0             0             40  United-States  <=50K
# 48840             0             0             20  United-States  <=50K
# 48841         15024             0             40  United-States   >50K
#
# [45185 rows x 15 columns]

# %%
print("Duplicated Rows:", df.duplicated().sum())
# Out:
# Duplicated Rows: 0

# %% [markdown]
# ### **Aggregating Data** (.groupby)
#
# Aggregating data involves summarizing data points into meaningful statistics,
# such as averages, sums, or counts, which can be achieved using GroupBy operations or pivot tables.
# This helps in understanding the dataset at a higher level.

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'working hours', 'country', 'income'],
#       dtype='object')

# %%
df['occupation'].unique()
# Out:
# array(['Machine Operator', 'Farming and Fishing', 'Protective Services',
#        'Other-service', 'Prof-specialty', 'Craft-repair', 'Adm-clerical',
#        'Exec-managerial', 'Tech-support', 'Sales', 'Priv-house-serv',
#        'Transport-moving', 'Handlers-cleaners', 'Armed-Forces',
#        'Unemployed'], dtype=object)

# %%
# Getting the average age for each occupation.

age_series = df.groupby('occupation')['age'].mean()
age_series
# Out:
# occupation
# Adm-clerical           37.218609
# Armed-Forces           31.785714
# Craft-repair           38.970882
# Exec-managerial        42.211371
# Farming and Fishing    41.400000
# Handlers-cleaners      32.606846
# Machine Operator       37.711298
# Other-service          35.051613
# Priv-house-serv        43.682609
# Prof-specialty         40.531578
# Protective Services    38.890256
# Sales                  37.446253
# Tech-support           37.208598
# Transport-moving       40.721934
# Unemployed             19.900000
# Name: age, dtype: float64

# %%
# Apply a function to the age column
def age_squared(age):
    return age ** 2
age_squared_series = df['age'].apply(age_squared)
age_squared_series
# Out:
# 0         625
# 1        1444
# 2         784
# 3        1936
# 5        1156
#          ...
# 48837     729
# 48838    1600
# 48839    3364
# 48840     484
# 48841    2704
# Name: age, Length: 45185, dtype: int64
